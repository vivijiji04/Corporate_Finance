# %% [markdown]
# ![vgu_campus.png](..\images\fscampus_small2.png)
#
# ***Finance III (PFIN)-SS2025***
#
# **Dr. Omer Cayirli**
#
# Lecturer in Empirical Finance
#
# omer.cayirli@vgu.edu.vn
#
# ---

# %% [markdown]
# ## Lecture 06
# ---

# %% [markdown]
# ### Outline
# *   The Dividend-Discount Model
#
# *   Sources of growth
#
# *   The Discounted Free Cash Flow Model (DCF Valuation)
#
# ---

# %% [markdown]
# ### The Dividend-Discount Model
#
# *   Suppose an investor buys a stock at today's price, $P_0$, to hold for one year, with the expectation that there will be a dividend payment of $D_1$ at t=1. Investor requires an r % return for this stock. In this case, the investor will make the following calculation:
#     $$ P_0 = \frac{D_1}{(1+r)} + \frac{P_1}{(1+r)} $$
# *   At the end of year 1;
#     $$ P_1 = \frac{D_2}{(1+r)} + \frac{P_2}{(1+r)} $$
#     $$ P_0 = \frac{D_1}{(1+r)} + \frac{\frac{D_2}{(1+r)} + \frac{P_2}{(1+r)}}{(1+r)} = \frac{D_1}{(1+r)} + \frac{D_2+P_2}{(1+r)^2} = \frac{D_1}{(1+r)} + \frac{D_2}{(1+r)^2} + \frac{P_2}{(1+r)^2} $$
# *   If we carry this logic to infinity, then we have the following equation;
#     $$ P_0 = \frac{D_1}{(1+r)} + \frac{D_2}{(1+r)^2} + \frac{D_3}{(1+r)^3} + ... = \sum_{t=1}^{\infty} \frac{D_t}{(1+r)^t} $$
# *   This is, in fact, a perpetuity. So;
#     $$ P_0 = \sum_{t=1}^{\infty} \frac{D_t}{(1+r)^t} = \frac{D}{r} $$
#
# ---

# %% [markdown]
# ### The Dividend-Discount Model
#
# *   What is the main assumption in this pricing equation?
#     $$ P_0 = \frac{D}{r} $$
# *   If dividends are expected to grow at a constant rate of g, then we have a perpetuity with growth.
#     $$ P_0 = \frac{D}{r-g} $$
# *   An investor is considering purchasing the shares of AGE Corp. The expected return of the investor is 12%. The company will pay a cash dividend of €3 per share after one year. The dividends paid by the company are expected to grow by 7% each year. What is the maximum price the investor would be willing to pay for this stock?
#     $$ P_0 = \frac{3}{0.12 - 0.07} = €60 $$
# *   Without dividend growth;
#     $$ P_0 = \frac{3}{0.12} = €25 $$
#
# ---

# %% [markdown]
# ### The Dividend-Discount Model
#
# *   An investor is considering purchasing the shares of AGE Corp. The expected return of the investor is 12%. The company will pay a cash dividend of €3 per share after one year. The dividends paid by the company are expected to grow by 7% for the next 2 years, and then by 5%. What is the maximum price the investor would be willing to pay for this stock?
#     $$ P_0 = \underbrace{\frac{3}{(1+0.12)}}_{t_1} + \underbrace{\frac{3(1 + 0.07)}{(1 + 0.12)^2}}_{t_2} + \underbrace{\frac{3(1 + 0.07)^2}{(1 + 0.12)^3}}_{t_3} + \underbrace{\frac{\frac{3(1 + 0.07)^2 * (1 + 0.05)}{0.12 - 0.05}}{(1 + 0.12)^3}}_{t_4} $$
#     $$ P_0 = 2.6786 + 2.5590 + 2.4448 + 36.6713 $$
#     $$ P_0 = €44.35 $$
# *   It is important to predict the dividend growth rate as accurately as possible in the dividend discount model.
# *   Firms can be in different growth stages:
#     *   **Growth Stage:** Sales are increasing rapidly, high profit margins, high growth in earnings per share, the company has many new investment opportunities, and the dividend payout ratio is low.
#     *   **Transition Stage:** Decreased growth rate and profit margin due to competition, fewer new investment opportunities, higher dividend payout rate.
#     *   **Maturity Stage:** Stage in which profit growth, dividend payout rate, and average return on investments stabilize over the remaining life of the firm.
#
# ---

# %% [markdown]
# ### The Dividend-Discount Model
#
# $$ \text{Earnings}_{(t=1)} = \text{Earnings}_{(t=0)} + (\text{Retained Earnings}_0 \times \text{ROE}) $$
# Let $NI$ be Net Income, $RE$ be Retained Earnings, and $ROE$ be Return on Equity (on new investments).
# $$ NI_1 = NI_0 + (RE_0 \times ROE) $$
# Divide by $NI_0$:
# $$ \frac{NI_1}{NI_0} = \frac{NI_0}{NI_0} + \frac{RE_0}{NI_0} \times ROE $$
# Let $g$ be the growth rate of earnings, so $\frac{NI_1}{NI_0} = (1+g)$.
#
# Let $p$ be the dividend payout ratio, so $\frac{RE_0}{NI_0}$ is the retention ratio $b = (1-p)$.
#
# $$ (1 + g) = 1 + (1-p) \times ROE $$
# $$ g = (1 - p) \times ROE $$
# Also, $p_t = \frac{D_t}{NI_t}$.
# $$ \text{If the payout ratio } p \text{ is constant (i.e., } p_0 = p_1 = p \text{), then } \frac{D_1}{D_0} = \frac{p \cdot NI_1}{p \cdot NI_0} = \frac{NI_1}{NI_0} = (1+g) $$
#
# ---

# %% [markdown]
# ### Growth, Reinvestment, and Return on Invested Capital (ROIC)
#
# *   Consider a business whose operating earnings (NOPAT) for the next year are expected to be the same as this year unless new net investment is made into its core operations.
#     *   Net Investment = Capital Expenditures - Depreciation + Change in Non-Cash Working Capital.
#     *   This net investment is expected to generate a return, measured by ROIC or RONIC.
#
#     Let NOPAT be Net Operating Profit After Tax and Let $RR$ be the Reinvestment Rate, which is the fraction of NOPAT that is put into Net Investment
#     $$ \text{NOPAT}_{(t=1)} = \text{NOPAT}_{(t=0)} + (\text{Net Investment}_0 \times \text{ROIC}) $$
#     $$ \text{Net Investment}_0 = RR \times \text{NOPAT}_{(t=0)} \quad \Rightarrow \quad \text{NOPAT}_{(t=1)} = \text{NOPAT}_{(t=0)} + (RR \times \text{NOPAT}_{(t=0)} \times \text{ROIC}) $$
#     $$ \frac{\text{NOPAT}_{(t=1)}}{\text{NOPAT}_{(t=0)}} = \frac{\text{NOPAT}_{(t=0)}}{\text{NOPAT}_{(t=0)}} + \frac{RR \times \text{NOPAT}_{(t=0)} \times \text{ROIC}}{\text{NOPAT}_{(t=0)}} $$
#     $$ (1 + g) = 1 + (RR \times \text{ROIC}) $$
#     $$ g = RR \times \text{ROIC} $$
#     Where:
#     *   $g$ = Sustainable growth rate of NOPAT (and often FCFF, if payout policies related to NOPAT are stable).
#     *   $RR = \frac{\text{Net Investment}}{\text{NOPAT}}$ (Reinvestment Rate from NOPAT).
#     *   $ROIC = \frac{\text{NOPAT}}{\text{Invested Capital}}$ (Return on Invested Capital, or RONIC if new investments earn differently.
#
# * A firm's operating growth is driven by how much it reinvests from its operating profits and the return it earns on those new investments.
# * If a firm maintains a constant Reinvestment Rate and a constant ROIC, its NOPAT and FCFF will grow at this rate $g$.
# ---

# %% [markdown]
# ### The Dividend-Discount Model
#
# *   Alpha Corp. (Α) reported a net profit of \$40 million for the year 2023. The company's board has decided to distribute 45\% of this profit as dividends. Alpha Corp. consistently achieves a ROE of 18\% on its new investments. What is the expected dividend growth rate ($g$) if Alpha Corp. maintains a constant dividend payout ratio?
#
#     $$ g = (\text{Retention Ratio}) \times ROE \quad \Rightarrow \quad g = (1 - \text{Payout Ratio}) \times ROE \quad \Rightarrow \quad g = (1 - 0.45) \times 0.18 \quad \Rightarrow \quad g = 9.9\% $$
#
# *   Alpha Corp. (Α) had 10 million shares outstanding at the end of 2023. Investors require a rate of return of 15% on Alpha Corp.'s shares ($r_E$). Calculate the estimated stock price of the company today ($P_0$) using the constant growth Dividend Discount Model (Gordon Growth Model).
#
#     *   Total Dividends Paid in 2023 = Net Profit $\times$ Payout Ratio $\quad \Rightarrow \quad \$40,000,000 \times 0.45 = \$18,000,000$
#     *   Shares Outstanding = $10,000,000$
#     *   $D_0 = \frac{\text{Total Dividends}}{\text{Shares Outstanding}} = \frac{\$18,000,000}{10,000,000} = \$1.80 \text{ per share}$
#
#     *   $D_1 = D_0 \times (1+g) \quad \Rightarrow \quad D_1 = \$1.80 \times (1 + 0.099) = \$1.9782 \text{ per share}$
#
#     *   $ P_0 = \frac{D_1}{r_E - g} \quad \Rightarrow \quad P_0 = \frac{\$1.9782}{0.15 - 0.099} \approx \$38.788 $
#
# *   The dividend discount model requires the dividend expected *next period* ($D_1$). Always ensure you are using the forward-looking dividend when $g > 0$.
#
# ---

# %% [markdown]
# ### The Dividend-Discount Model
#
# Epsilon Enterprises (Ε) just reported net income of $20 million for 2023 and paid out 50% as dividends. It has 4 million shares outstanding.
# Its ROE is expected to be 18% for the next two years (2024, 2025) before decreasing to a stable 12% in year 3 (2026) and onwards due to increased competition. The payout ratio is expected to remain constant at 50%.
# The required rate of return for Epsilon's stock is 15%.
#
# Calculate the current stock price ($P_0$) of Epsilon Enterprises using the multi-stage dividend discount model.
#
# ---
# *   $NI_0 = \$20,000,000$; Payout Ratio ($p$) = 50%; Shares = 4,000,000
# *   $D_0 = (\$20M \times 0.5) / 4M = \$10M / 4M = \$2.50$
# *   $ROE_1, ROE_2 = 18\%$ (for 2024, 2025)
# *   $ROE_3 \text{ onwards} = 12\%$ (for 2026 onwards)
# *   Required Return ($r$) = 15%
# ---
# *   Retention Rate ($b$) = $1 - p = 1 - 0.50 = 0.50$
# *   Growth Rate for Years 1 & 2 ($g_{1,2}$): $g_{1,2} = b \times ROE_1 = 0.50 \times 18\% = 9\%$
# *   Growth Rate from Year 3 onwards ($g_3$): $g_3 = b \times ROE_3 = 0.50 \times 12\% = 6\%$
# ---
# *   $D_0 = \$2.50$
# *   $D_1 (2024) = D_0 \times (1 + g_{1,2}) = \$2.50 \times (1 + 0.09) = \$2.50 \times 1.09 = \$2.725$
# *   $D_2 (2025) = D_1 \times (1 + g_{1,2}) = \$2.725 \times 1.09 = \$2.97025$
# *   $D_3 (2026) = D_2 \times (1 + g_3) = \$2.97025 \times (1 + 0.06) = \$2.97025 \times 1.06 = \$3.148465$
#
# ---

# %% [markdown]
# ### The Dividend-Discount Model
#
#
# *   $D_0 = \$2.50$
# *   $D_1 (2024) = D_0 \times (1 + g_{1,2}) = \$2.50 \times (1 + 0.09) = \$2.50 \times 1.09 = \$2.725$
# *   $D_2 (2025) = D_1 \times (1 + g_{1,2}) = \$2.725 \times 1.09 = \$2.97025$
# *   $D_3 (2026) = D_2 \times (1 + g_3) = \$2.97025 \times (1 + 0.06) = \$2.97025 \times 1.06 = \$3.148465$
# ---
# The constant growth phase starts with $D_3$.
# $$ P_2 = \frac{D_3}{r - g_3} \quad \Rightarrow \quad P_2 = \frac{\$3.148465}{0.15 - 0.06} \approx \$34.98294 $$
#
# $$ P_0 = \frac{D_1}{(1+r)^1} + \frac{D_2}{(1+r)^2} + \frac{P_2}{(1+r)^2} \quad \Rightarrow \quad P_0 = \frac{\$2.725}{(1.15)^1} + \frac{\$2.97025}{(1.15)^2} + \frac{\$34.98294}{(1.15)^2} \quad \Rightarrow \quad P_0 \approx \$31.07 $$
#
# | Year | Net Income ($M) | Payout ($M)  | Retained ($M) | ROE    | Shares (M) | Dps ($) | Growth |
# |:------:|-----------------:|--------------:|--------------:|--------:|------------:|---------:|--------:|
# | 2023 (0)| 20.000          | 10.000       | 10.000       |        | 4          | 2.5000  |        |
# | 2024 (1)| 21.800          | 10.900       | 10.900       | 18.00% | 4          | 2.7250  | 9.00%  |
# | 2025 (2)| 23.762          | 11.881       | 11.881       | 18.00% | 4          | 2.9703  | 9.00%  |
# | 2026 (3)| 25.188          | 12.594       | 12.594       | 12.00% | 4          | 3.1485  | 6.00%  |
#
# ---

# %% [markdown]
# ### The Dividend Discount Model: Components of Return
#
# *   Using the **Constant Growth Dividend Discount Model**, the price of a stock ($P_0$) is:
#     $$ P_0 = \frac{D_1}{r-g} \quad \Rightarrow \quad r = \frac{D_1}{P_0} + g $$
#     Where $D_1$ is the expected dividend next year, $r$ is the required rate of return, and $g$ is the constant dividend growth rate.
#
# *   **Components of the Expected Total Return ($r$):**
#
#     1.  **Dividend Yield:** $\frac{D_1}{P_0}$
#     2.  **Capital Gains Yield (or Price Return):** $g$
#         *   In the constant growth model, the stock price is expected to grow at the same rate as the dividends ($g$).
#
#         $$P_1 = \frac{D_2}{r-g} = \frac{D_1(1+g)}{r-g} \quad \text{and} \quad \frac{P_1 - P_0}{P_0} = \frac{P_1}{P_0} - 1 \quad \Rightarrow \quad \frac{P_1}{P_0} = \frac{D_1(1+g)/(r-g)}{D_1/(r-g)} = 1+g$$
#
# *   According to the DDM, the expected total return on a stock is the sum of its expected dividend yield and its expected capital gains yield (price appreciation rate):
#     $$ \text{Expected Total Return } (r) = \text{Dividend Yield } \left(\frac{D_1}{P_0}\right) + \text{Capital Gains Yield } (g) $$
#
# ---

# %% [markdown]
# ### The Dividend-Discount Model
#
# Epsilon Dynamics (Ε) reported a net profit of $8,000,000 for the year 2023. The company follows a policy of distributing 40% of its net profit as dividends. Epsilon Dynamics has 2,000,000 shares outstanding. The company's Return on Equity (ROE) is consistently 15%, and its shares are currently trading at $30 in the market.
#
# 1.  What is the expected rate of return (required rate of return, $r$) that investors expect when purchasing Epsilon Dynamics stocks?
#
# 2.  What is the expected stock price of Epsilon Dynamics after 1 year ($P_1$)?
#
# The sustainable growth rate is the rate at which the company can grow its earnings and dividends without changing its financing policy.
# $$ g = \text{Retention Rate} \times ROE = (1 - p) \times ROE \quad \Rightarrow \quad  g = (1 - 0.40) \times 0.15 = 0.60 \times 0.15 = 0.09 = 9\% $$
#
# $$ EPS_0 = \frac{\text{Net Profit}}{\text{Shares Outstanding}} = \frac{\$8,000,000}{2,000,000} = \$4.00  \quad \Rightarrow \quad D_0 = EPS_0 \times p = \$4.00 \times 0.40 = \$1.60 $$
#
# $$ D_1 = D_0 \times (1 + g) = \$1.60 \times (1 + 0.09) = \$1.60 \times 1.09 = \$1.744$$
# $$\quad \text{or} \quad EPS_1 = EPS_0 \times (1 + g) = \$4.00 \times 1.09 = \$4.36  \quad \Rightarrow \quad D_1 = EPS_1 \times p = \$4.36 \times 0.40 = \$1.744$$
#
# $$ r = \frac{D_1}{P_0} + g \quad \Rightarrow \quad r = \frac{\$1.744}{\$30} + 0.09 \quad \Rightarrow \quad r \approx 0.058133 + 0.09 \approx 14.81\% $$
#
# Assuming the growth rate and required return remain constant, the stock price is expected to grow at the same rate as dividends.
# $$ P_1 = P_0 \times (1 + g) \quad \Rightarrow \quad P_1 = \$30 \times (1 + 0.09) = \$32.70 $$
#
# **Alternatively, using the DDM for $P_1$:**
#
# $$D_2 = D_1 \times (1 + g) = \$1.744 \times 1.09 = \$1.90096 \quad \Rightarrow \quad P_1 = \frac{D_2}{r - g} = \frac{\$1.90096}{0.148133 - 0.09} \approx \$32.70 $$
#
# ---

# %% [markdown]
# ### The Dividend Discount Model: Present Value of Growth Opportunities (PVGO)
# *   The stock price can be decomposed into two components:
#     *   The present value of earnings under zero growth.
#     *   The present value of growth opportunities.
#
# * Beta Enterprises (Β) has an expected Earnings Per Share ($EPS_1$) of €5.00 for the coming year. The company maintains a dividend payout ratio ($p$) of 40% and earns a Return on Equity (ROE) of 20% on new investments. The required rate of return ($r$) on Beta Enterprises' stock is 15%.
#
# 1.  Calculate the expected dividend per share next year ($D_1$).
# 2.  Calculate the expected growth rate of dividends ($g$).
# 3.  Calculate the current stock price assuming zero growth ($P_{ng}$), where all earnings are paid out as dividends.
# 4.  Calculate the current stock price with the given payout ratio and growth ($P_g$).
# 5.  Determine the Present Value of Growth Opportunities (PVGO).
#
# ---

# %% [markdown]
# ### The Dividend Discount Model: Present Value of Growth Opportunities (PVGO)
# * Beta Enterprises (Β) has an expected Earnings Per Share ($EPS_1$) of €5.00 for the coming year. The company maintains a dividend payout ratio ($p$) of 40% and earns a Return on Equity (ROE) of 20% on new investments. The required rate of return ($r$) on Beta Enterprises' stock is 15%.
#
# 1.  Calculate the expected dividend per share next year ($D_1$).
# 2.  Calculate the expected growth rate of dividends ($g$).
# 3.  Calculate the current stock price assuming zero growth ($P_{ng}$), where all earnings are paid out as dividends.
# 4.  Calculate the current stock price with the given payout ratio and growth ($P_g$).
# 5.  Determine the Present Value of Growth Opportunities (PVGO).
#
# Given: $EPS_1 = €5.00$, $p = 0.40$ (payout ratio), $ROE = 0.20$, $r = 0.15$, $\; \text{and}$ Retention rate ($b$) = $1 - p = 1 - 0.40 = 0.60$.
#
# **1. Expected Dividend per Share ($D_1$):**
#    $D_1 = p \times EPS_1 = 0.40 \times €5.00 = €2.00$
#
# **2. Expected Growth Rate of Dividends ($g$):**
#    $g = b \times ROE = (1 - p) \times ROE = 0.60 \times 0.20 = 0.12 \quad (12.0\%)$
#
# **3. Stock Price with Zero Growth ($P_{ng}$):**
#    (This implies $p=1$, so $b=0$, thus $g=0$, and $D_1 = EPS_1$)
#    $P_{ng} = \frac{EPS_1}{r} = \frac{€5.00}{0.15} = €33.33$
#
# **4. Current Stock Price with Growth ($P_g$):**
#    (Using $D_1 = €2.00$ and $g = 0.12$)
#    $P_g = \frac{D_1}{r - g} = \frac{€2.00}{0.15 - 0.12} = \frac{€2.00}{0.03} = €66.67$
#
# **5. Present Value of Growth Opportunities (PVGO):**
#    $PVGO = P_g - P_{ng}$
#    $PVGO = €66.67 - €33.33 = €33.34$
#
#    Alternatively:
#    $PVGO = P_g - \frac{EPS_1}{r} = €66.67 - \frac{€5.00}{0.15} = €66.67 - €33.33 = €33.34$
#
# ---

# %% [markdown]
# ### The Dividend Discount Model: Present Value of Growth Opportunities (PVGO)
#
# Beta Dynamics (Β)'s earnings and dividends per share are expected to grow indefinitely by 6% a year. Beta Dynamics earns 15% on its new invested capital (ROE = 15%). Next year's dividend ($D_1$) is projected to be $2.00, and the required rate of return on its stock ($r$) is 10%.
#
# 1.  What is the current stock price ($P_0$)?
# 2.  What is Beta Dynamics' dividend payout ratio ($p$)?
# 3.  What is the present value of its growth opportunities (PVGO)?
# 4.  Suppose that Beta Dynamics' high growth will stop after year 3 (i.e., growth applies to $D_1, D_2, D_3$). In year 4 and afterward, it will pay out all earnings as dividends (i.e., payout ratio $p=1$, so $g=0$ from year 4 onwards). What would be Beta Dynamics' stock price ($P_0$) under this new growth assumption?
#
# ---

# %% [markdown]
# ### The Dividend Discount Model: Present Value of Growth Opportunities (PVGO)
#
# Beta Dynamics (Β)'s earnings and dividends per share are expected to grow indefinitely by 6% a year. Beta Dynamics earns 15% on its new invested capital (ROE = 15%). Next year's dividend ($D_1$) is projected to be $2.00, and the required rate of return on its stock ($r$) is 10%.
#
#
# $g = 0.06$, $ROE = 0.15$, $D_1 = \$2.00$, $r = 0.10$
#
# $ P_0 = \frac{D_1}{r-g} = \frac{\$2.00}{0.10 - 0.06} = \$50.00 $
#
# $g = (1 - p) \times ROE \quad \Rightarrow \quad 0.06 = (1 - p) \times 0.15 \quad \Rightarrow \quad = 60\%) $
#
# $ D_1 = p \times EPS_1 \implies \$2.00 = 0.60 \times EPS_1 = \$3.3333 $
#
# Price if no growth ($P_{ng}$), where all earnings are paid out $EPS_1$ becomes $D_1$ for a no-growth firm:
#
# $ P_{ng} = \frac{EPS_1}{r} = \frac{\$3.3333}{0.10} = \$33.3333 $
#
# $ PVGO = P_0 - P_{ng} = \$50.00 - \$33.3333 = \approx \$16.67 $
#
# **4. Stock Price if Growth Stops After Year 3: Projected Cash Flows**
#
# *   Assumptions: Growth ($g=6\%$) for 3 years, then $g=0$ and payout ratio ($p=100\%$) from Year 4.
# *   $EPS_1 = \$3.3333$ (calculated from $D_1/p = \$2.00/0.60$)
#
# | Year | Growth Rate | $EPS_t$  | Payout Ratio ($p_t$) | $D_t = EPS_t \times p_t$ |
# |:----:|:-----------:|---------:|:--------------------:|-----------------------:|
# | 1    | 6.0%        |  $3.3333 | 60%                  |                $2.0000 |
# | 2    | 6.0%        |  $3.5333 | 60%                  |                $2.1200 |
# | 3    | 6.0%        |  $3.7453 | 60%                  |                $2.2472 |
# | 4    | 0.0%        |  $3.7453 | 100%                 |                $3.7453 |
# | 5+   | 0.0%        |  $3.7453 | 100%                 |                $3.7453 |
#
# *   $D_4$ = $EPS_4 = EPS_3 \times (1+g_3) = \$3.7453 \times (1+0) = \$3.7453$.
#
# *   Terminal value at the end of year 3 ($P_3$), which is the PV of dividends from year 4 onwards:
#
#     $ P_3 = \frac{D_4}{r - g_{terminal}} = \frac{D_4}{r} = \frac{\$3.7453}{0.10} = \$37.4533 $
#
# *   Current stock price ($P_0$) with two-stage growth:
#
#     $ P_0 = \frac{D_1}{(1+r)} + \frac{D_2}{(1+r)^2} + \frac{D_3 + P_3}{(1+r)^3}  \quad \Rightarrow \quad P_0 = \frac{\$2.00}{(1.10)} + \frac{\$2.12}{(1.10)^2} + \frac{\$2.2472 + \$37.4533}{(1.10)^3} \quad \Rightarrow \quad P_0 \approx \$33.3979 $
#
# ---

# %% [markdown]
# ### Share Repurchases and the Total Payout Model
# *   An alternative method that may be more reliable when a firm repurchases shares.
# *   Values all of the firm's equity
#     $$ P_0 = \frac{\text{PV (Future Total Dividends and Repurchases)}}{\text{Shares Outstanding } (t = 0)} $$
#
# * Epsilon Dynamics has 150 million shares outstanding and expects earnings of $600 million at the end of this coming year. Epsilon plans to maintain a total payout ratio of 60% of its earnings. Both earnings and payouts are expected to grow at a constant rate of 5% per year indefinitely. If Epsilon's equity cost of capital is 12%, what is its current share price?
#
# $$ Payout_1 = E_1 \times \text{Total Payout Ratio} \quad \Rightarrow \quad Payout_1 = \$600 \text{ million} \times 0.60 = \$360 \text{ million} $$
#
# $$ PV_{\text{Equity}} = \frac{Payout_1}{r_E - g} \quad \Rightarrow \quad PV_{\text{Equity}} = \frac{\$360 \text{ million}}{0.12 - 0.05} = \frac{\$360 \text{ million}}{0.07} \quad \Rightarrow \quad PV_{\text{Equity}} \approx \$5,142.857 \text{ million} $$
#
# $$ P_0 = \frac{PV_{\text{Equity}}}{\text{Shares Outstanding}} \quad \Rightarrow \quad P_0 = \frac{\$5,142.857 \text{ million}}{150 \text{ million shares}} \approx \$34.2857 \text{ per share} $$
#
# ---

# %% [markdown]
# ### The Discounted Free Cash Flow Model (DCFM)
# *   Discounted cash flow valuation
#     *   The value of any asset is the expected cash flows from that asset discounted at a rate that reflects their riskiness (Intrinsic value)
#     *   The value of any asset is a function of
#         *   the cash flows generated by that asset,
#         *   the life of the asset,
#         *   the expected growth in the cash flows,
#         *   the riskiness associated with these cash flows.
#             $$ \text{Value of Asset} = \sum_{t=1}^{N} \frac{E(CF_t)}{(1+r)^t} $$
# *   A firm is a portfolio of assets.
# *   To value a firm, we can use cash flows to the firm over its life and a discount rate that reflects the collective risk of the firm's assets.
#     *   Some of the assets of a firm have already been created.
#     *   A significant component of firm value reflects expectations about future investments.
#     *   We not only need to measure the cash flows from current investments but also must estimate the expected value from future investments.
#
#
# ---

# %% [markdown]
# ### The Discounted Free Cash Flow Model (DCFM)
# *   Equity Valuation vs. Firm Valuation
#     *   Value just the equity stake in the business;
#     *   Value the entire firm
#     *   Both approaches discount expected cash flows, but the relevant cash flows and discount rates are different for each.
# *   The value of equity
#     *   Obtained by discounting expected cash flows to equity (the residual cash flows after meeting all operating expenses, tax obligations, and interest and principal payments) at the cost of equity (the rate of return required by equity investors in the firm).
#         $$ \text{Value of Equity} = \sum_{t=1}^{N} \frac{E(\text{CF to equity}_t)}{(1+r_e)^t} $$
# *   The value of the firm
#     *   Obtained by discounting expected cash flows to the firm (residual cash flows after meeting all operating expenses, taxes, and reinvestment needs, but prior to debt payments) using WACC (the cost of the different components of financing used by the firm, weighted by their market-value proportions).
#         $$ \text{Value of Firm} = \sum_{t=1}^{N} \frac{E(\text{CF to firm}_t)}{(1 + \text{WACC})^t} $$
# ---

# %% [markdown]
# ### The Discounted Free Cash Flow Model (DCFM)
#
# *   The choice between free cash flows to equity (FCFE) and free cash flows to the firm (FCFF) is a choice between equity and firm valuation.
# *   Done consistently, both approaches should yield the same values for the equity in a business.
#     *   The cash flows to equity are after net debt issues or payments and become much more difficult to estimate when financial leverage is changing over time.
#     *   The cash flows to the firm are pre-debt cash flows and are unaffected by changes in financial leverage. Therefore, firm valuation may be more straightforward.
#
# <div style="position: relative; margin: 20px width: 100%; /* Allow text to flow naturally */">
#
#   <!-- This is the container for the diagram, which will overlay -->
#   <div style="width: 720px; margin: 20px auto 30px auto; /* Negative top margin to pull it up */
#               border-top: 2px solid #FFFFFF; /* White line to match diagram's spine */
#               position: relative; height: 280px; /* Explicit height */
#               z-index: 10; /* Attempt to bring it forward */
#               /* background-color: rgba(255, 255, 255, 0.1); /* Optional: Slight tint if needed */">
#
# <!-- Left Box -->
# <div style="position: absolute; top: 80px; left: -80px; width: 230px; border: 1.5px solid #555; padding: 10px; background-color: #FFFFFF; box-shadow: 3px 3px 7px rgba(0,0,0,0.3); text-align: left; color: #000000; z-index:11;">
#       <strong>What are the cashflows from existing assets?</strong>
#       <ul style="padding-left: 20px; margin-top: 5px; font-size: 0.9em;">
#         <li>Equity: Cashflows after debt payments</li>
#         <li>Firm: Cashflows before debt payments</li>
#       </ul>
#     </div>
#
# <!-- Top Middle Box -->
# <div style="position: absolute; top: 20px; left: 50%; transform: translateX(-50%); width: 300px; border: 1.5px solid #555; padding: 10px; background-color: #FFFFFF; box-shadow: 3px 3px 7px rgba(0,0,0,0.3); text-align: left; color: #000000; z-index:11;">
#       <strong>What is the value added by growth assets?</strong><br>
#       <span style="font-size: 0.9em;">Equity: Growth in equity earnings/ cashflows<br>
#       Firm: Growth in operating earnings/ cashflows</span>
#     </div>
#
# <!-- Bottom Middle Box -->
# <div style="position: absolute; top: 150px; left: 50%; transform: translateX(-50%); width: 300px; border: 1.5px solid #555; padding: 10px; background-color: #FFFFFF; box-shadow: 3px 3px 7px rgba(0,0,0,0.3); text-align: left; color: #000000; z-index:11;">
#       <strong>How risky are the cash flows from both existing assets and growth assets?</strong><br>
#       <span style="font-size: 0.9em;">Equity: Risk in equity in the company<br>
#       Firm: Risk in the firm's operations</span>
#     </div>
#
# <!-- Right Box -->
# <div style="position: absolute; top: 105px; right: -80px; width: 230px; border: 1.5px solid #555; padding: 10px; background-color: #FFFFFF; box-shadow: 3px 3px 7px rgba(0,0,0,0.3); text-align: left; color: #000000; z-index:11;">
#       <strong>When will the firm become a mature firm, and what are the potential roadblocks?</strong>
#     </div>
#   </div>
# </div>
#
# ---

# %% [markdown]
# ### The Discounted Free Cash Flow Model (DCFM)
#
# *   Stable growth rate
#     *   Because the growth rate in the firm's cash flows is expected to last forever, the firm's other measures of performance (including revenues, earnings, and reinvestment) can be expected to grow at the same rate.
#
#     *   In the long run, a firm cannot grow at a rate significantly greater than the growth rate in the economy in which it operates.
#         *   If the valuation is done in nominal (real) terms, the stable growth rate cannot be larger than the nominal (real) growth rate in the economy in which the firm operates.
#
#     *   Can a stable growth rate be much lower than the growth rate in the economy?
#
#     *   Rule of thumb: The stable growth rate should not exceed the risk-free rate used in a valuation. The risk-free rate can be decomposed into an expected inflation rate and an expected real interest rate.
#
#     *   If we assume that the real growth rate of an economy will be equal to the real interest rate in the long run, the risk-free rate becomes a proxy for the nominal growth rate in the economy.
#
# ---

# %% [markdown]
# ### The Discounted Free Cash Flow Model (DCFM)
#
# *   ROE vs ROIC
#     *   ROE looks at how much profit a company makes per dollar of shareholders' equity.
#
#     *   ROIC is a measure of how much cash a company gets back for each dollar it invests in its business.
#
#     $$ROE = \frac{\text{Net Income}}{\text{Book Value of Equity}_{(t-1)}} \quad \text{and} \quad ROIC = \frac{\text{Operating Income} * (1 - \text{tax rate})}{\text{Book Value of Invested Capital}_{(t-1)}} $$
#
#     *   Companies that have generated ROICs higher than their WACC for many years running usually have a moat.
#
#     *   But a positive spread between ROIC and WACC alone doesn't justify an economic moat.
#
#     *   Investors also have to think about the qualitative attributes such as high barriers to entry, huge market share, low-cost production, corporate culture, patents, or high customer switching costs that create an economic moat around a company's profits.
#
# *   Invested Capital
#
# $$ \text{Invested Capital} = \text{Total Assets} - (\text{Non-Interest-Bearing Current Liabilities}) $$
#
# NIBCLs: Items like Accounts Payable, Accrued Expenses, etc. Spontaneous sources of financing that reduce the need for explicit investor-supplied capital for operations.
#
# $$ \text{NIBCLs} \approx \text{Total Current Liabilities} - \text{Short-term Interest-Bearing Debt} \\
# \Rightarrow \quad \text{Invested Capital} = \text{Total Assets} - (\text{Total Current Liabilities} - \text{Short-term Debt}) $$
#
# $$ \text{Invested Capital} = \text{Book Value of Equity} + \text{Book Value of Debt} - \text{Non-Operating Assets (e.g., Excess Cash, Marketable Securities not core to operations)} $$
#
# $$ ROE = ROIC + \frac{\text{Debt}}{\text{Equity}} (\text{ROIC} - \text{After-tax cost of debt}) $$
#
# ---

# %% [markdown]
# ### The Discounted Free Cash Flow Model - FCFF
# *   Allows us to value a firm without explicitly forecasting its dividends, share repurchases, or its use of debt.
# *   Enterprise value:
#     *   The net cost of acquiring the firm's equity, taking its cash, paying off all debt (owning the unlevered business).
#     *   We start with the PV of the free cash flow (FCF) that the firm has available to pay all investors.
#
#     $$ \text{Free Cash Flow} = \underbrace{(\text{EBIT}) \times (1 – \tau_c)}_{\text{Unlevered Net Income}} + \text{Depreciation} – \text{CapEx} – \Delta \text{NWC} $$
#     $$ \text{Net Investment} = \text{CapEx} – \text{Depreciation} \quad \Rightarrow \quad \text{Free Cash Flow} = \text{EBIT} \times (1 – \tau_c) – \text{Net Investment} – \Delta \text{NWC} $$
#     $$ \text{Enterprise Value} = V_0 = \text{PV (Future Free Cash Flow of Firm)} $$
#     $$ \text{Enterprise Value} = \text{Market Value of Equity} + \text{Debt} - \text{Cash} $$
#     $$ \text{Market Value of Equity} = \text{Enterprise Value} + \text{Cash} – \text{Debt} $$
#     $$ P_0 = \frac{V_0 + \text{Cash}_0 - \text{Debt}_0}{\text{Shares Outstanding}_0} $$
#
# ---

# %% [markdown]
# ### The Discounted Free Cash Flow Model - FCFF
# *   Discount rate
#     *   Since we need to discount the free cash flows to all investors of the firm, WACC is the choice.
#
#     *   WACC reflects the average risk of all of the firm's investments.
#         $$ V_0 = \frac{FCF_1}{(1+r_{WACC})^1} + \frac{FCF_2}{(1+r_{WACC})^2} + ... + \frac{FCF_N + V_N}{(1+r_{WACC})^N} $$
#         $$ V_N = \frac{FCF_{N+1}}{r_{WACC} – g_{FCF}} = FCF_N \left( \frac{1+g_{FCF}}{r_{WACC} - g_{FCF}} \right) $$
#         Where,
#         $V_0$ is the enterprise value
#         $V_N$ is the terminal value
#         $g_{FCF}$ is the growth rate for FCF beyond the forecast period.
# *   Value of company is sum of value from explicit DCF forecast and the discounted continuation (terminal) value.
#
# *   Value of common equity is value of company minus value of claims of investors of higher priority (debt, preferred stock).
#
# *   Capital structure weights
#     *   Always use market values if available
#     *   Book values of debt may be close if debt is highly rated. Market values often not available.
#
# ---

# %% [markdown]
# ### The Discounted Free Cash Flow Model - FCFF
#
# BSA Corp. reported revenues of $600 million in the last fiscal year. Revenue growth is projected as follows: 12% for the next two years (Year 1 and Year 2), 9% for the following two years (Year 3 and Year 4), and stabilizing at a 5% growth rate thereafter.
#
# The company maintains a gross margin of 30%. Depreciation is 6% of revenues, and capital expenditures are 8% of revenues during the high-growth period. For every $1 increase in revenue, $0.15 in additional net working capital (NWC) is required. The corporate tax rate is 20%.
#
# BSA Corp. is an all-equity firm with 150 million shares outstanding, and its estimated cost of equity is 13%.
#
# Calculate the fair share price of BSA Corp. based on these assumptions using a Free Cash Flow to Firm (FCFF) valuation approach.
#
# ---

# %% [markdown]
# ### The Discounted Free Cash Flow Model - FCFF
#
# **Projected FCFF for Years 1-5 and Terminal Value Calculation:**
#
# | Year                 | 0     | 1        | 2        | 3        | 4        | 5 (Start Stable) |
# |----------------------|-------:|----------:|----------:|----------:|----------:|-----------------:|
# | Revenue Growth       |       | 12.0%    | 12.0%    | 9.0%     | 9.0%     | 5.0%            |
# | **Revenues**         | 600.00| 672.00   | 752.64   | 820.38   | 894.21   | 938.92          |
# | COGS (70%)           |       | 470.40   | 526.85   | 574.27   | 625.95   | 657.24          |
# | Gross Profit         |       | 201.60   | 225.79   | 246.11   | 268.26   | 281.68          |
# | Depreciation (6%)    |       | 40.32    | 45.16    | 49.22    | 53.65    | 56.34           |
# | EBIT                 |       | 161.28   | 180.63   | 196.89   | 214.61   | 225.34          |
# | Taxes (20%)          |       | 32.26    | 36.13    | 39.38    | 42.92    | 45.07           |
# | **NOPAT (EBIT(1-T))**|       | **129.02**| **144.50**| **157.51**| **171.69**| **180.27**      |
# | + Depreciation       |       | 40.32    | 45.16    | 49.22    | 53.65    | 56.34           |
# | - CAPEX (8%)         |       | 53.76    | 60.21    | 65.63    | 71.54    | *See TV Note*   |
# | - $\Delta$NWC        |       | 10.80    | 12.10    | 10.16    | 11.08    | *See TV Note*   |
# | **FCFF**             |       | **104.78**| **117.35**| **130.94**| **142.72**| **110.94 (Year 5 for TV)**|
#
# *   $\Delta$ NWC Calculations (Examples):
#     *   Yr 1: $(672.00 - 600.00) \times 0.15 = 10.80$
#     *   Yr 4: $(894.21 - 820.38) \times 0.15 = 11.08$
#
# *   **Terminal Value (TV) Calculation (at end of Year 4, using $FCFF_5$):**
#
#     $FCFF_5 = NOPAT_5 \times (1 - g/WACC) = \$180.27 \times (1 - 0.05/0.13) \approx \$180.27 \times (1 - 0.3846) \approx \$110.94$
#
#     $TV_4 = \frac{FCFF_5}{WACC - g} = \frac{110.94}{0.13 - 0.05} = \frac{110.94}{0.08} = 1386.75$
#
# **Discounting FCFFs and Terminal Value:**
#
# | Year                 | FCFF     | PV Factor (13%) | PV of FCFF |
# |----------------------|----------:|-----------------:|------------:|
# | 1                    | 104.78   | 0.884956        | 92.72      |
# | 2                    | 117.35   | 0.783147        | 91.90      |
# | 3                    | 130.94   | 0.693050        | 90.75      |
# | 4                    | 142.72   | 0.613319        | 87.54      |
# | **Sum of PV(Explicit FCFFs Y1-4)** |        |                 | **362.91** |
# | PV of $TV_4$         |          | 0.613319 (Yr 4) | 850.57 ($1386.75 \times 0.613319$) |
#
# **Enterprise Value (EV):**
# $EV = \text{Sum of PV(Explicit FCFFs)} + PV(TV_4)$
# $EV = 362.91 + 850.57 = 1213.48$
#
# **Equity Value and Share Price:**
#
# Since BSA Corp. is an all-equity firm, assuming no non-operating cash or debt, $\Rightarrow$ Equity Value = Enterprise Value = $1213.48 million
#
# $\text{Share Price} = \frac{\text{Equity Value}}{\text{Shares Outstanding}} \quad \Rightarrow \quad \text{Share Price} = \frac{\$1213.48 \text{ million}}{150 \text{ million shares}} \approx \$8.09 \text{ per share}$
#
# ---

# %% [markdown]
# ### The Discounted Free Cash Flow Model - FCFF
# *   A firm's FCF is equal to the sum of the free cash flows from the firm's current and future investments.
#
# *   The firm's enterprise value is the total NPV that the firm will earn from continuing its existing projects and initiating new ones.
#
# *   The NPV of any individual project represents its contribution to the firm's enterprise value.
#
# *   To maximize the firm's share price, we should accept projects that have a positive NPV.
#
# ---

# %% [markdown]
# ### The Discounted Free Cash Flow Model - FCFF
#
# Epsilon Dynamics (Ε) reported sales of $300 million for the most recent year (Year 0). Sales are projected to grow as follows: 10% in Year 1, 8% in Year 2, and 6% in Year 3. From Year 4 onwards, sales are expected to grow at a constant long-run rate of 3%.
#
# **Financial Projections & Assumptions:**
# *   EBIT: 12% of Sales.
# *   Net Investment (CapEx - Depreciation): 5% of the increase in Sales ($\Delta$Sales) from the previous year.
# *   Increase in Net Working Capital (NWC): 8% of the increase in Sales ($\Delta$Sales) from the previous year.
# *   Corporate Tax Rate ($\tau_C$): 28%.
# *   Weighted Average Cost of Capital (WACC): 9.5%.
#
# **Current Financial Position (End of Year 0):**
# *   Cash and Equivalents: $50 million.
# *   Total Debt: $20 million.
# *   Shares Outstanding: 15 million.
#
# Estimate the value of Epsilon Dynamics' stock per share at the beginning of Year 1 (i.e., end of Year 0).
#
# ---

# %% [markdown]
# ### The Discounted Free Cash Flow Model - FCFF
#
# **1. Forecast Free Cash Flow to Firm (FCFF) for Years 1-4 ($ millions):**
#
# | Item                         | Year 0 | Year 1 (g=10%) | Year 2 (g=8%) | Year 3 (g=6%) | Year 4 (g=3%) |
# |------------------------------|--------:|----------------:|---------------:|---------------:|---------------:|
# | Sales Growth Rate            |        | 10.0%          | 8.0%          | 6.0%          | 3.0%          |
# | Sales                        | 300.0  | 330.0          | 356.4         | 377.8         | 389.1         |
# | $\Delta$Sales from Prior Year|        | 30.0           | 26.4          | 21.4          | 11.3          |
# | EBIT (12% of Sales)          |        | 39.60          | 42.77         | 45.33         | 46.69         |
# | Less: Taxes (28% of EBIT)    |        | (11.09)        | (11.98)       | (12.69)       | (13.07)       |
# | **NOPAT**                    |        | **28.51**      | **30.79**     | **32.64**     | **33.62**     |
# | Less: Net Investment (5% $\Delta$Sales)|    | (1.50)         | (1.32)        | (1.07)        | (0.57)        |
# | Less: Inc. in NWC (8% $\Delta$Sales)|     | (2.40)         | (2.11)        | (1.71)        | (0.91)        |
# | **FCFF**                     |        | **24.61**      | **27.36**     | **29.86**     | **32.15**     |
#
# *   $Sales_1 = 300.0 \times (1+0.10) = 330.0$
# *   $\Delta \text{Sales}_1 = 330.0 - 300.0 = 30.0$
# *   $\text{EBIT}_1 = 330.0 \times 0.12 = 39.60$
# *   $\text{Taxes}_1 = 39.60 \times 0.28 \approx 11.09$
# *   $\text{NOPAT}_1 = 39.60 - 11.09 = 28.51$
# *   $\text{Net Inv.}_1 = 30.0 \times 0.05 = 1.50$
# *   $\text{Inc. NWC}_1 = 30.0 \times 0.08 = 2.40$
# *   $\text{FCFF}_1 = 28.51 - 1.50 - 2.40 = 24.61$
#
# **2. Calculate Terminal Value ($V_{T}$) at the end of Year 3:**
#    $$ V_{T, \text{Year 3}} = \frac{FCFF_4}{WACC - g} = \frac{\$32.15 \text{ M}}{0.095 - 0.03} = \frac{\$32.15 \text{ M}}{0.065} \approx \$494.62 \text{ M} $$
#
# **3. Calculate Enterprise Value ($V_0$) at the end of Year 0:**
#    $$V_0 = PV(FCFF_1) + PV(FCFF_2) + PV(FCFF_3) + PV(V_{T, \text{Year 3}}) \quad \Rightarrow \quad V_0 = \frac{\$24.61}{(1.095)^1} + \frac{\$27.36}{(1.095)^2} + \frac{\$29.86}{(1.095)^3} + \frac{\$494.62}{(1.095)^3} \\ \Rightarrow \quad V_0 \approx \$444.76 \text{ M} $$
#
# **4. Calculate Equity Value ($E_0$):**
#    $$E_0 = \text{Enterprise Value } (V_0) + \text{Cash}_0 - \text{Debt}_0 \quad \Rightarrow \quad E_0 = \$444.76 \text{ M} + \$50 \text{ M} - \$20 \text{ M} = \$474.76 \text{ M} $$
#
# **5. Calculate Value per Share ($P_0$):**
#    $$P_0 = \frac{\text{Equity Value}}{\text{Shares Outstanding}_0} \quad \Rightarrow \quad P_0 = \frac{\$474.76 \text{ M}}{15 \text{ million shares}} \approx \$31.65 \text{ per share} $$
#
# ---

# %% [markdown]
# ### The Discounted Free Cash Flow Model - FCFF
# *   Valuing a company's equity using enterprise DCF is a four-part process:
#
#     1.  Value the company's operations by discounting free cash flow at the weighted average cost of capital.
#
#     2.  Identify and value nonoperating assets, such as excess cash and marketable securities, nonconsolidated subsidiaries, and other assets not included in free cash flow. Summing the value of operations and nonoperating assets gives gross enterprise value.
#
#     3.  Identify and value all debt and other nonequity claims against the enterprise value. Debt and other nonequity claims include fixed-rate and floating-rate debt, debt equivalents such as unfunded pension liabilities and restructuring provisions, employee options, preferred stock, among others.
#
#     4.  Subtract the value of debt and other nonequity claims from enterprise value to determine the value of common equity. To estimate value per share, divide equity value by the number of current shares outstanding.
#
# ---

# %% [markdown]
# ### The Discounted Free Cash Flow Model - FCFF
#
# Epsilon Dynamics (Ε) reported sales of $1,200 million in 2023 (Year 0). Its sales are projected to grow at an 8% rate for the next four years (Years 1-4), before stabilizing at a 4% growth rate in Year 5 and thereafter.
#
# The company's operating costs are 80% of its revenues. It pays a corporate tax rate of 25%. Epsilon Dynamics has $400 million in long-term debt outstanding, on which it pays 6% interest annually; this debt level is expected to be maintained.
#
# Depreciation amounts to 5% of revenues. Capital expenditures (CAPEX) are planned to be 6% of revenues for the next two years (Years 1-2). Starting in Year 3, CAPEX is projected to equal depreciation expense. The company requires net working capital (NWC) equivalent to 10% of its revenues. Epsilon Dynamics currently holds $50 million in excess cash, an amount it plans to maintain.
#
# The company's weighted average cost of capital (WACC) is 10% and is expected to remain at this level. Epsilon Dynamics has 80 million shares outstanding.
#
# **Estimate the intrinsic value per share for Epsilon Dynamics stock given these assumptions, using the FCFF valuation model.**
#
# ---

# %% [markdown]
# ### The Discounted Free Cash Flow Model - FCFF
#
# **Input Assumptions Table (Years 1-5 are forecast, Year 5 is first year of stable growth)**
# | Year                      | 0        | 1        | 2        | 3        | 4        | 5 (Stable) |
# |---------------------------|----------:|----------:|----------:|----------:|----------:|------------:|
# | Revenue Growth            |          | 8.0%     | 8.0%     | 8.0%     | 8.0%     | 4.0%       |
# | Operating costs/Revenues  |          | 80.0%    | 80.0%    | 80.0%    | 80.0%    | 80.0%      |
# | Depreciation (% Rev)      |          | 5.0%     | 5.0%     | 5.0%     | 5.0%     | 5.0%       |
# | Debt Outstanding ($m)     | 400      | 400      | 400      | 400      | 400      | 400        |
# | Interest Rate on Debt     |          | 6.0%     | 6.0%     | 6.0%     | 6.0%     | 6.0%       |
# | CAPEX (% Rev)             |          | 6.0%     | 6.0%     | 5.0%     | 5.0%     | 5.0%       |
# | NWC (% Rev)               | 10.0%    | 10.0%    | 10.0%    | 10.0%    | 10.0%    | 10.0%      |
# | Tax Rate                  | 25.0%    | 25.0%    | 25.0%    | 25.0%    | 25.0%    | 25.0%      |
# | WACC                      | 10.0%    | 10.0%    | 10.0%    | 10.0%    | 10.0%    | 10.0%      |
#
# **Projected Income Statement & FCFF Calculation ($ millions)**
# | Year                         | 0        | 1         | 2         | 3         | 4         | 5         |
# |------------------------------|----------:|----------:|----------:|----------:|----------:|------------:|
# | Revenues                     | 1200.00  | 1296.00   | 1399.68   | 1511.65   | 1632.59   | 1697.89   |
# | Operating costs (80%)        | 960.00   | 1036.80   | 1119.74   | 1209.32   | 1306.07   | 1358.31   |
# | Depreciation (5% of Rev)     | 60.00    | 64.80     | 69.98     | 75.58     | 81.63     | 84.89     |
# | **Operating Profits (EBIT)** | **180.00**| **194.40**| **209.95**| **226.75**| **244.89**| **254.69**|
# | Interest Expense (6% of $400m)| 24.00    | 24.00     | 24.00     | 24.00     | 24.00     | 24.00     |
# | Earnings Before Taxes (EBT)  | 156.00   | 170.40    | 185.95    | 202.75    | 220.89    | 230.69    |
# | Taxes on EBT (25%)           | 39.00    | 42.60     | 46.49     | 50.69     | 55.22     | 57.67     |
# | Net Income                   | 117.00   | 127.80    | 139.46    | 152.06    | 165.66    | 173.01    |
# |                              |          |           |           |           |           |           |
# | **FCFF Calculation**         |          |           |           |           |           |           |
# | EBIT                         | 180.00   | 194.40    | 209.95    | 226.75    | 244.89    | 254.69    |
# | - Taxes on EBIT (25% of EBIT)| 45.00    | 48.60     | 52.49     | 56.69     | 61.22     | 63.67     |
# | **Unlevered Net Income (NOPAT)**| **135.00**| **145.80**| **157.46**| **170.06**| **183.66**| **191.01**|
# | + Depreciation               | 60.00    | 64.80     | 69.98     | 75.58     | 81.63     | 84.89     |
# | - CAPEX                      |          | 77.76     | 83.98     | 75.58     | 81.63     | 84.89     |
# | - ΔNWC (10% of ΔRev)         |          | 9.60      | 10.37     | 11.20     | 12.09     | 6.53      |
# | **FCFF**                     |          | **123.24**| **133.09**| **158.87**| **171.57**| **184.48**|
# | PV(FCFF) at 10% WACC         |          | 112.04    | 110.00    | 119.36    | 117.16    |           |
# | **PV(FCFF) first 4 years**   | **458.55**|           |           |           |           |           |
# | Terminal Value (End Yr 4)    |          |           |           |           | **3074.67**|           |
# | PV(Terminal Value)           | **2100.04**|           |           |           |           |           |
# | **Enterprise Value (EV)**    | **2558.59**|           |           |           |           |           |
#
# *Notes for FCFF Calculation:*
# *   *CAPEX Yr1-2 = 6% of Revenues; Yr3+ = 5% of Revenues (equals Depreciation).*
# *   *Δ NWC = Δ(Revenues × 10%). e.g., Δ NWC Yr1 = (1296.00 - 1200.00) × 0.10 = 9.60.*
# *   *Terminal Value (End of Year 4, TV₄) = FCFF₅ / (WACC - g) = 184.48 / (0.10 - 0.04) = 3074.67.*
# *   *PV(Terminal Value) = TV₄ / (1 + WACC)⁴ = 3074.67 / 1.10⁴ = 2100.04.*
#
# $$
# V_0 = \sum_{t=1}^{4} \frac{FCFF_t}{(1 + WACC)^t} + \frac{TV_4}{(1 + WACC)^4}
# $$
#
# $$
# TV_4 = \frac{FCFF_5}{WACC - g}
#       = \frac{184.48}{0.10 - 0.04}
#       = \$3074.67\text{ million}
# $$
#
# $$
# V_0
# = \frac{123.24}{1.10}
# + \frac{133.09}{1.10^2}
# + \frac{158.87}{1.10^3}
# + \frac{171.57 + 3074.67}{1.10^4}
# \;\to\;
# 112.04 + 109.99 + 119.37 + \frac{3246.24}{1.4641}
# \;\to\;
# \$2558.59\text{ million}
# $$
#
# $$
# \text{Equity Value}
# = \text{Enterprise Value} + \text{Cash}_0 - \text{Debt}_0
# \;\to\;
# \$2558.59\text{ million} + \$50\text{ million} - \$400\text{ million}
# = \$2208.59\text{ million}
# $$
#
# $$
# P_0
# = \frac{\text{Equity Value}}{\text{Shares Outstanding}_0}
# \;\to\;
# \frac{\$2208.59\text{ million}}{80\text{ million shares}}
# \approx \$27.61\text{ per share}
# $$
#
# ---

# %% [markdown]
# ### Exercise 6.1
#
# Phi Ltd just paid $D_0=1.50$. Dividends grow at $g=6\%$ forever. Required return is $r_1=20\%$ for $t=1\text{–}3$ and $r_2=12\%$ thereafter. What is $P_0$?
#
# ---

# %% [markdown]
# ### Exercise 6.2
#
# Omega Corporation earned $20 million for the fiscal year ending yesterday ($E_0 = 20\text{m}$). The firm paid out 40% of its earnings as dividends yesterday ($p = 40\%$) and will maintain this payout ratio annually at year-end. The company has 4 million shares outstanding, a current stock price of $50 ($P_0 = 50$), and an expected perpetual ROE of 15% ($\text{ROE} = 15\%$). What is the required rate of return on the stock?
#
# ---

# %% [markdown]
# ### Exercise 6.3
#
# Quantum Systems plans to pay a dividend of $3.50 this year ($D_1 = \$3.50$). The company has an expected earnings growth rate of 4.5% per year and an equity cost of capital of 11.5%.
#
# 1.  Assuming Quantum's dividend payout rate and expected growth rate remain constant, and Quantum does not issue or repurchase shares, estimate Quantum's share price ($P_0$).
#
# 2.  Suppose Quantum Systems decides to pay a dividend of $1.20 this year ($D_1 = \$1.20$) and use the remaining funds it would have paid as dividends to repurchase shares. If Quantum's total payout rate remains constant (implying total payout per share is still what would have been the $3.50 dividend), estimate Quantum's share price ($P_0$).
#
# 3.  If Quantum Systems maintains the new dividend of $1.20 per share and the repurchase policy from part (2), and its overall earnings grow at 4.5%, at what rate are Quantum's dividends per share, earnings per share, and share price expected to grow in the future?
#
# ---

# %% [markdown]
# ### Exercise 6.4
#
# Omega Corp has earnings of $18 million projected for next year ($E_1 = 18$m) and grows at constant rate $g_0 = 4\%$ forever. Currently, $70\%$ of earnings are paid as dividends ($p_0 = 0.70$) and plans to maintain this rate unless additional internal funding is needed.
#
# The company will launch a new project at end of Year 1, completely internally funded, requiring an additional $25\%$ retention of Year 2 earnings. The project generates revenues starting Year 3 and earns the same return as current invested capital.
#
# Omega has 6 million shares outstanding. Find stock value if discount rate is $r = 12\%$.
#
# ---

# %% [markdown]
# ### Exercise 6.5:
#
# Delta Technologies is a privately held developer of advanced security systems. In late 2023 you initiate discussions with Sigma's founder about acquiring the business at end of 2023. Estimate the value of Sigma per share using discounted FCF approach:
#
# - Debt: $28 million
# - Excess cash: $15 million
# - Shares outstanding: 4 million
# - Expected FCF in 2024 ($FCF_1$): $6.8 million
# - Expected FCF in 2025 ($FCF_2$): $8.5 million
# - Future FCF growth rate beyond 2025 ($g$): 7%
# - Weighted-average cost of capital (WACC): 11%
#
# ---

# %% [markdown]
# ### Exercise 6.6:
#
# Sigma Enterprises has projected sales of $140 million next year (Sales₁=$140m). Costs are expected to be $85 million (Costs₁=$85m) and net investment is expected to be $18 million (NetInv₁=$18m). Each of these values is expected to grow at 10 percent for the next three years (Years 1, 2, 3). The growth rate is expected to decline to 5 percent per year thereafter (g_stable=5%), and it is expected to remain at that level indefinitely. The company has outstanding debt currently valued at $25 million and estimated excess cash of $6 million. There are 3 million shares outstanding and investors require a 14 percent return (WACC=14%). The corporate tax rate is 35 percent (Tc=35%). What is your estimate of the current stock price?
#
# ---

# %% [markdown]
# ### What is next?
#
# *   **Suggested problems**
#     *   Ch. 9: 1, 2, 3, 4, 7, 8, 10, 11, 12, 15, 18, 19, 21.
#
# *   **Next Lecture**
#     *   More on DCF valuation
#         *   Flow-to-equity approach
#         *   Adjusted Present Value (APV) approach
#
# ---
