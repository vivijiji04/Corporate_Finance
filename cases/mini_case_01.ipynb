# %% [markdown]
# ### Case Study: Helios Renewables (Η) - Navigating Growth and a Greener Future
#
# **Introduction & Current Landscape:**
#
# Helios Renewables (Η), an established firm in the renewable energy sector, has built a solid reputation on its portfolio of operating solar farms. These existing operations are projected by analysts to generate a steady $50 million in free cash flow (FCF) each year indefinitely. The company operates in a jurisdiction with a corporate tax rate of 30%. Current market conditions indicate a risk-free rate of 3%, and investors typically demand a market risk premium of 7% for investments of this nature.
#
# Helios' CFO, Ben Carter, recently reviewed the firm's financial standing. The equity markets value Helios' shares at a total of $300 million. Alongside this, the company carries $200 million in debt on its books, which currently costs them 6.0% annually before taxes. Based on their current financial structure and market perception, Helios' equity has a beta of 1.20. The debt, while not explicitly traded with a public beta, is estimated by analysts to have a beta of 0.20.
#
# CEO Anya Sharma is now looking to the future and has called a strategy meeting to discuss the company's financial health and a significant new investment opportunity.
#
# **Part 1: Understanding Helios' Current Financial Health**
#
# Before considering new ventures, Anya and Ben need a clear picture of their current financial metrics.
# 1.  Calculate Helios' current:
#
#     a.  Cost of Equity ($r_E$).
#
#     b.  After-tax Cost of Debt.
#
#     c.  Unlevered Beta ($\beta_U$), representing the risk of Helios' underlying assets.
#
#     d.  Unlevered Cost of Capital ($r_U$).
#
#     e.  Current Weighted Average Cost of Capital ($r_{WACC}$).
#
# 2.  Briefly explain the difference between the systematic and idiosyncratic risks Helios faces. Which type of risk is primarily compensated in their cost of equity?
#
# **Part 2: The "Project Aurora" Opportunity & Financing Considerations**
#
# Anya is particularly excited about "Project Aurora," a promising venture into geothermal energy. Initial assessments suggest it requires an upfront investment of $100 million. Once operational, it's expected to add a perpetual $12 million in annual FCF, starting next year. The board believes this new venture carries a business risk profile very similar to Helios' existing solar operations.
#
# Ben Carter is evaluating financing options. "If we were to go the traditional route and fund this like our other assets," he muses, "what would that look like?" He's also been reading about Modigliani-Miller and the potential benefits of debt due to taxes. "Alternatively," he adds, "what if we took this opportunity to issue $100 million in new, permanent debt specifically for Project Aurora? Our bankers indicate we could likely get a 6% rate on that new debt as well."
#
# Later, during a strategy session, board member David Lee suggests a more aggressive shift: "Perhaps this project is a catalyst. What if we aim for a new overall firm debt-to-equity ratio of 1.0 after incorporating Project Aurora and its financing? How would that change our cost of capital picture, assuming our cost of debt and debt beta remain stable even at that higher leverage?"
#
# **Your Task for Part 2:**
# Analyze Project Aurora under different scenarios:
# 1.  Baseline Evaluation (as an all-equity project for valuation purposes):
#
#     a.  What discount rate should be used for Project Aurora if its financing is assumed to maintain the firm's current overall asset risk profile ($r_U$)?
#
#     b.  Calculate the Net Present Value of the project if viewed as an all-equity venture ($NPV_U$).
#
# 2.  Value of Project with Debt Financing & Tax Shield:
#
#     a.  If Project Aurora is financed entirely with $100 million of new permanent debt, what is the Present Value of the Interest Tax Shield ($PV(ITS)$) generated by this specific project debt?
#
#     b.  What is the total value contributed by Project Aurora to the firm if it is undertaken and financed with this new debt (considering its unlevered NPV and the PV of the project's debt tax shield)?
#
# 3.  Revised Firm Capital Structure (Target D/E = 1.0):
#     Assume Project Aurora is undertaken and its value (calculated as $NPV_U + PV(ITS)_{\text{project}}$ from 2.b) is added to the initial firm value. The firm then recapitalizes its entire balance sheet (existing assets + new project) to achieve a new target overall Debt-to-Equity ratio of 1.0. Calculate the firm's new:
#
#     a.  Equity Beta ($\beta_E$) and Cost of Equity ($r_E$).
#
#     b.  Weighted Average Cost of Capital ($r_{WACC}$).
#
# 4.  Considering Personal Taxes: An analyst mentions that investor-level taxes can alter the picture. If typical investors face a 35% tax on interest income ($\tau_i$) and an effective 15% tax on equity income ($\tau_e$), calculate the effective tax advantage of debt ($\tau^*$) for Helios using its corporate tax rate.
#
# **Part 3: Strategic Decisions, Market Realities, and Broader Implications**
#
# The board discussion continues, moving beyond pure calculations to the strategic implications of their capital structure.
#
# Board member Sarah Chen remarks, "Ben, your numbers show debt is cheaper than equity. To minimize our WACC, shouldn't we always lean heavily on debt?" Another member, Tom Evans, chimes in, "And if leveraging up boosts our EPS, that's clearly good for shareholders, right?"
#
# Anya Sharma, however, is more cautious. "While the tax benefits of debt are clear on paper," she states, "we operate in the real world. What are the other, perhaps less tangible, factors and potential downsides we need to weigh when considering more debt, especially for a large project like Aurora or a more significant shift in our overall leverage?" She's also concerned about how the market might interpret a large equity issuance if they chose that route instead, given that the management team believes Helios' stock is fairly valued.
#
# A junior analyst then asks about a recent news article discussing a competitor, "Zephyr Energy," which is heavily indebted. Zephyr recently passed on a profitable small-scale wind farm expansion because, as some speculate, the benefits would have primarily gone to its existing bondholders, leaving little for its equity investors who would have had to fund the expansion.
#
# **Your Task for Part 3:**
# Address the board's points and Anya's concerns:
# 1.  Debunking Fallacies:
#
#     a.  Respond to Sarah Chen's comment about "cheaper debt" implying maximum leverage. Explain the underlying principle from MM theory (even with taxes) that she might be overlooking.
#
#     b.  Address Tom Evans' point about maximizing EPS. Is this always aligned with maximizing shareholder wealth? Explain.
#
# 2.  The Trade-Off Theory in Practice:
#
#     a.  Beyond taxes, what are the key potential costs of increasing debt that Helios should consider (e.g., financial distress, agency costs)?
#
#     b.  Conversely, are there any potential agency benefits to increasing debt for a company like Helios?
#
#     c.  How might the specific nature of Helios' assets (long-lived, specialized solar and potentially geothermal plants) affect its sensitivity to financial distress costs?
#
#     d.  Explain the situation at "Zephyr Energy" in the context of debt overhang. How could Zephyr potentially resolve this issue to undertake profitable projects?
#
# 3.  Information, Incentives, and Market Signals:
#
#     a.  If management was primarily concerned about maintaining control (managerial entrenchment), how might this influence their preferred debt level compared to one that purely maximizes firm value through tax shields?
#
#     b.  If Helios needed funds for Project Aurora but management privately believed Helios' stock was undervalued, how might this affect their preference between debt and equity financing, according to the Pecking Order Theory? What signal might a new equity issue send in this scenario?
#
# 4.  Equity Issuance and "Dilution": If Project Aurora adds positive value to the firm (as implied by your calculation in Part 2.2.b) and Helios decided to fund the $100 million investment entirely by issuing new shares at the current fair market price, would this "dilute" the value per share for existing shareholders? Explain the impact on share price.
#
# ---
